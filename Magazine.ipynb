# %%
from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1118, 885)
        Form.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0.175, y1:0.886364, x2:1, y2:0, stop:0.0348259 rgba(62, 6, 56, 255), stop:0.164179 rgba(93, 0, 84, 255), stop:0.427861 rgba(153, 68, 139, 255), stop:0.711443 rgba(91, 18, 72, 255), stop:0.905473 rgba(46, 6, 36, 255), stop:1 rgba(55, 0, 43, 255));\n"
"")
        self.frame = QtWidgets.QFrame(Form)
        self.frame.setGeometry(QtCore.QRect(210, 30, 691, 101))
        self.frame.setStyleSheet("background-color: rgb(255,255,255);\n"
"border-width: 2px;\n"
"border-radius: 50px;\n"
"")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(20, 30, 661, 41))
        self.label.setStyleSheet("color: rgb(74, 0, 89);\n"
"font: 20pt \"Stencil 93\";")
        self.label.setAlignment(QtCore.Qt.AlignCenter)
        self.label.setObjectName("label")
        self.frame_2 = QtWidgets.QFrame(Form)
        self.frame_2.setGeometry(QtCore.QRect(40, 160, 1021, 521))
        self.frame_2.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 14pt \"Poor Richard\";\n"
"color: rgb(74, 0, 89);\n"
"\n"
"border-radius : 50px;\n"
"\n"
"\n"
"\n"
"")
        self.frame_2.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_2.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_2.setObjectName("frame_2")
        self.label_3 = QtWidgets.QLabel(self.frame_2)
        self.label_3.setGeometry(QtCore.QRect(60, 30, 141, 31))
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(self.frame_2)
        self.label_4.setGeometry(QtCore.QRect(60, 90, 161, 31))
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(self.frame_2)
        self.label_5.setGeometry(QtCore.QRect(60, 150, 151, 31))
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(self.frame_2)
        self.label_6.setGeometry(QtCore.QRect(60, 200, 181, 41))
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(self.frame_2)
        self.label_7.setGeometry(QtCore.QRect(60, 270, 141, 31))
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(self.frame_2)
        self.label_8.setGeometry(QtCore.QRect(60, 450, 171, 31))
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(self.frame_2)
        self.label_9.setGeometry(QtCore.QRect(550, 30, 201, 31))
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(self.frame_2)
        self.label_10.setGeometry(QtCore.QRect(550, 90, 131, 31))
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(self.frame_2)
        self.label_11.setGeometry(QtCore.QRect(550, 150, 161, 41))
        self.label_11.setObjectName("label_11")
        self.label_12 = QtWidgets.QLabel(self.frame_2)
        self.label_12.setGeometry(QtCore.QRect(550, 210, 201, 41))
        self.label_12.setObjectName("label_12")
        self.label_13 = QtWidgets.QLabel(self.frame_2)
        self.label_13.setGeometry(QtCore.QRect(550, 320, 131, 41))
        self.label_13.setObjectName("label_13")
        self.female = QtWidgets.QLineEdit(self.frame_2)
        self.female.setGeometry(QtCore.QRect(250, 90, 241, 31))
        self.female.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.female.setObjectName("female")
        self.income = QtWidgets.QLineEdit(self.frame_2)
        self.income.setGeometry(QtCore.QRect(250, 30, 241, 31))
        self.income.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.income.setObjectName("income")
        self.clg = QtWidgets.QLineEdit(self.frame_2)
        self.clg.setGeometry(QtCore.QRect(250, 210, 241, 31))
        self.clg.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.clg.setObjectName("clg")
        self.marriage = QtWidgets.QLineEdit(self.frame_2)
        self.marriage.setGeometry(QtCore.QRect(250, 150, 241, 31))
        self.marriage.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.marriage.setObjectName("marriage")
        self.professional = QtWidgets.QLineEdit(self.frame_2)
        self.professional.setGeometry(QtCore.QRect(250, 270, 241, 31))
        self.professional.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.professional.setObjectName("professional")
        self.residence = QtWidgets.QLineEdit(self.frame_2)
        self.residence.setGeometry(QtCore.QRect(250, 450, 241, 31))
        self.residence.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.residence.setObjectName("residence")
        self.dualincome = QtWidgets.QLineEdit(self.frame_2)
        self.dualincome.setGeometry(QtCore.QRect(750, 30, 241, 31))
        self.dualincome.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.dualincome.setObjectName("dualincome")
        self.minors = QtWidgets.QLineEdit(self.frame_2)
        self.minors.setGeometry(QtCore.QRect(750, 90, 241, 31))
        self.minors.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.minors.setObjectName("minors")
        self.own = QtWidgets.QLineEdit(self.frame_2)
        self.own.setGeometry(QtCore.QRect(750, 150, 241, 31))
        self.own.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.own.setObjectName("own")
        self.house = QtWidgets.QLineEdit(self.frame_2)
        self.house.setGeometry(QtCore.QRect(750, 210, 241, 31))
        self.house.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.house.setObjectName("house")
        self.english = QtWidgets.QLineEdit(self.frame_2)
        self.english.setGeometry(QtCore.QRect(750, 330, 241, 31))
        self.english.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.english.setObjectName("english")
        self.label_16 = QtWidgets.QLabel(self.frame_2)
        self.label_16.setGeometry(QtCore.QRect(60, 330, 181, 31))
        self.label_16.setObjectName("label_16")
        self.label_17 = QtWidgets.QLabel(self.frame_2)
        self.label_17.setGeometry(QtCore.QRect(60, 390, 181, 31))
        self.label_17.setObjectName("label_17")
        self.retired = QtWidgets.QLineEdit(self.frame_2)
        self.retired.setGeometry(QtCore.QRect(250, 330, 241, 31))
        self.retired.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.retired.setObjectName("retired")
        self.unemployed = QtWidgets.QLineEdit(self.frame_2)
        self.unemployed.setGeometry(QtCore.QRect(250, 390, 241, 31))
        self.unemployed.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.unemployed.setObjectName("unemployed")
        self.label_18 = QtWidgets.QLabel(self.frame_2)
        self.label_18.setGeometry(QtCore.QRect(550, 380, 171, 41))
        self.label_18.setObjectName("label_18")
        self.prevchild = QtWidgets.QLineEdit(self.frame_2)
        self.prevchild.setGeometry(QtCore.QRect(750, 390, 241, 31))
        self.prevchild.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.prevchild.setObjectName("prevchild")
        self.label_19 = QtWidgets.QLabel(self.frame_2)
        self.label_19.setGeometry(QtCore.QRect(550, 440, 171, 41))
        self.label_19.setObjectName("label_19")
        self.prevparent = QtWidgets.QLineEdit(self.frame_2)
        self.prevparent.setGeometry(QtCore.QRect(750, 450, 241, 31))
        self.prevparent.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.prevparent.setObjectName("prevparent")
        self.label_15 = QtWidgets.QLabel(self.frame_2)
        self.label_15.setGeometry(QtCore.QRect(550, 260, 201, 41))
        self.label_15.setObjectName("label_15")
        self.race = QtWidgets.QLineEdit(self.frame_2)
        self.race.setGeometry(QtCore.QRect(750, 270, 241, 31))
        self.race.setStyleSheet("QLineEdit { \n"
"background-color: rgb(207, 207, 207);\n"
"color: rgb(3, 3, 3);\n"
"font: 11pt \"Microsoft YaHei\";\n"
"border: 2px solid rgb(207, 207, 207);\n"
"}\n"
"QLineEdit:focus {\n"
"border: 2px solid  rgb(74, 0, 89);\n"
"}\n"
"")
        self.race.setObjectName("race")
        self.frame_3 = QtWidgets.QFrame(Form)
        self.frame_3.setGeometry(QtCore.QRect(40, 710, 1021, 141))
        self.frame_3.setStyleSheet("background-color: rgb(255,255,255);\n"
"color: rgb(74, 0, 89);\n"
"border-radius: 30px;\n"
"font: 20pt  \"Poor Richard\";\n"
"")
        self.frame_3.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame_3.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame_3.setObjectName("frame_3")
        self.label_14 = QtWidgets.QLabel(self.frame_3)
        self.label_14.setGeometry(QtCore.QRect(60, 20, 471, 91))
        self.label_14.setObjectName("label_14")
        self.result = QtWidgets.QLabel(self.frame_3)
        self.result.setGeometry(QtCore.QRect(570, 80, 411, 51))
        font = QtGui.QFont()
        font.setFamily("Poor Richard")
        font.setPointSize(20)
        font.setBold(False)
        font.setItalic(False)
        font.setWeight(50)
        self.result.setFont(font)
        self.result.setText("")
        self.result.setObjectName("result")
        self.pushButton = QtWidgets.QPushButton(self.frame_3)
        self.pushButton.setGeometry(QtCore.QRect(580, 20, 251, 51))
        self.pushButton.setStyleSheet("QPushButton{\n"
"background-color: rgb(74, 0, 89); \n"
"font: 16pt \"MV Boli\";\n"
"color: rgb(255,255,255);\n"
"border-radius:10px;\n"
"border: 2px solid rgb(74, 0, 89); \n"
"}\n"
"QPushButton:hover{\n"
"background-color: rgb(184, 81, 169);\n"
"\n"
"color:rgb(255,255,255);\n"
"}\n"
"")
        self.pushButton.setObjectName("pushButton")
        self.pushButton.clicked.connect(self.predict)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
    def predict(self):
        income = self.income.text()
        x1 = int(income)
        
        female = self.female.text()
        if female == "female":
            x2 = 1
        else:
            x2 = 0
            
        marriage = self.marriage.text()
        if marriage == "yes":
            x3 = 1
        else:
            x3 = 0
            
        clg = self.clg.text()
        if clg == "0":
            x4 = 0
        else:
            x4 = 1
            
        professional = self.professional.text()
        if professional == "yes":
            x5 = 1
        else:
            x5 = 0
        
        retired = self.retired.text()
        if retired == "yes":
            x6 = 1
        else:
            x6 = 0
        
        unemployed = self.unemployed.text()
        if unemployed == "yes":
            x7 = 1
        else:
            x7 = 0
            
        residence = self.residence.text()
        x8 = int(residence)
        
        dualincome = self.dualincome.text()
        if dualincome == "yes":
            x9 = 1
        else:
            x9 = 0
        
        minors = self.minors.text()
        if minors == "yes":
            x10 = 1
        else:
            x10 = 0
       
        own = self.own.text()
        if own == "yes":
            x11 = 1
        else:
            x11 = 0
       
        house = self.house.text()
        if house == "single family":
            x12 = 1
        else: 
            x12 = 0
        
        race = self.race.text()
        if race == "white":
            x13 = 1
        else: 
            x13 = 0
        
        english = self.english.text()
        if english == "english":
            x14 = 1
        else: 
            x14 = 0
        
        prevchild = self.prevchild.text()
        if prevchild == "yes":
            x15 = 1
        else:
            x15 = 0
        
        prevparent = self.prevparent.text()
        if prevparent == "yes":
            x16 = 1
        else:
            x16 = 0
        
        
        import pandas as pd
        import sklearn
        from sklearn.model_selection import train_test_split
        from sklearn.metrics import confusion_matrix
        from sklearn.metrics import accuracy_score
        from sklearn.svm import SVC
        from sklearn.preprocessing import StandardScaler

        path="D:/2022projects/Logistic/Magzine/Kid.csv"
        data=pd.read_csv(path)
        #print(data)

        inputs=data.drop(['Buy','Obs No.'],'columns')
        output=data['Buy']
        #print(inputs)
        #print(output)

        x_train,x_test,y_train,y_test=train_test_split(inputs,output,test_size=0.2)

        #sc=StandardScaler()
        #x_train=sc.fit_tranform(x_train)
        #x_test=sc.transform(x_test)

        model=SVC()  #initialize my model

        model.fit(x_train,y_train) #train the model

        y_pred=model.predict(x_test)
        #print(y_pred)

        res=model.predict(([[x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,x16]]))
        #print(ans)
        if res==0:
            resx='MAGAZINE NOT BOUGHT'
        else:
            resx='MAGAZINE BOUGHT'
        print(resx)
        res = str(resx)
        self.result.setText(resx)
        

        cm=confusion_matrix(y_test,y_pred)
        print("Confusion matrix:",cm)
        print("Accuracy:",accuracy_score(y_test,y_pred)*100)




    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Magzine Purchase Prediction"))
        self.label.setText(_translate("Form", "MAGZINE PURCHASE PREDICTION"))
        self.label_3.setText(_translate("Form", "Income:"))
        self.label_4.setText(_translate("Form", "Gender:"))
        self.label_5.setText(_translate("Form", "Is Married:"))
        self.label_6.setText(_translate("Form", "College Education:"))
        self.label_7.setText(_translate("Form", "Is Professional:"))
        self.label_8.setText(_translate("Form", "Residence:"))
        self.label_9.setText(_translate("Form", "Dual Income:"))
        self.label_10.setText(_translate("Form", "Minors:"))
        self.label_11.setText(_translate("Form", "Home ownership :"))
        self.label_12.setText(_translate("Form", "Resident type:"))
        self.label_13.setText(_translate("Form", "Language:"))
        self.label_16.setText(_translate("Form", "Is Retired:"))
        self.label_17.setText(_translate("Form", "Unemployed:"))
        self.label_18.setText(_translate("Form", "Prev Child Mag:"))
        self.label_19.setText(_translate("Form", "Prev Parent Mag:"))
        self.label_15.setText(_translate("Form", "Race(white or others):"))
        self.label_14.setText(_translate("Form", "Click here to predict whether person \n"
" buys magzine or not:"))
        self.pushButton.setText(_translate("Form", "PREDICT"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# C:\Users\91998\AppData\Local\Temp\ipykernel_11976\1350483885.py:444: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   inputs=data.drop(['Buy','Obs No.'],'columns')
# C:\Users\91998\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# MAGAZINE NOT BOUGHT
# Confusion matrix: [[100   5]
#  [  6  24]]
# Accuracy: 91.85185185185185
